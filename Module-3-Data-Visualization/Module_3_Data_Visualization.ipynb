# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Name": ["Aarav", "Priya", "Rahul", "Sneha", "Aditya",
             "Ananya", "Rohan", "Neha", "Vikram", "Ira"],
    "Age": [20, 21, 19, 20, 22, 21, 20, 19, 22, 21],
    "Gender": ["Male", "Female", "Male", "Female", "Male",
               "Female", "Male", "Female", "Male", "Female"],
    "Study_Hours": [3, 5, 2, 6, 4, 7, 3, 5, 2, 6],
    "Attendance": [85, 92, 78, 95, 88, 96, 82, 90, 75, 93],
    "Marks": [72, 88, 65, 91, 79, 95, 70, 86, 62, 90]
}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age  Gender  Study_Hours  Attendance  Marks
# 0   Aarav   20    Male            3          85     72
# 1   Priya   21  Female            5          92     88
# 2   Rahul   19    Male            2          78     65
# 3   Sneha   20  Female            6          95     91
# 4  Aditya   22    Male            4          88     79
# 5  Ananya   21  Female            7          96     95
# 6   Rohan   20    Male            3          82     70
# 7    Neha   19  Female            5          90     86
# 8  Vikram   22    Male            2          75     62
# 9     Ira   21  Female            6          93     90

# %%
plt.figure(figsize=(10, 5))

plt.bar(df["Name"], df["Marks"])

plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.plot(df["Name"], df["Marks"], marker="o")

plt.title("Student Marks Trend")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.xticks(rotation=45)

plt.show()

# %%
gender_counts = df["Gender"].value_counts()

plt.figure(figsize=(6, 6))

plt.pie(
    gender_counts,
    labels=gender_counts.index,
    autopct="%1.1f%%"
)

plt.title("Gender Distribution")

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.hist(df["Marks"], bins=5)

plt.title("Distribution of Student Marks")
plt.xlabel("Marks")
plt.ylabel("Number of Students")

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(df["Study_Hours"], df["Marks"])

plt.title("Study Hours vs Marks")
plt.xlabel("Study Hours")
plt.ylabel("Marks")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Study_Hours",
    y="Marks",
    hue="Gender"
)

plt.title("Study Hours vs Marks by Gender")

plt.show()

# %%
plt.figure(figsize=(8, 5))

correlation = df[["Age", "Study_Hours", "Attendance", "Marks"]].corr()

sns.heatmap(
    correlation,
    annot=True
)

plt.title("Correlation Heatmap")

plt.show()

# %%
# # Key Insights

# 1. The bar chart allows comparison of marks between students.

# 2. The line chart shows variation in student marks.

# 3. The pie chart represents the gender distribution.

# 4. The histogram shows how marks are distributed.

# 5. The scatter plot helps examine the relationship between study hours
#    and marks.

# 6. The correlation heatmap provides a numerical view of relationships
#   #  between numerical variables.
