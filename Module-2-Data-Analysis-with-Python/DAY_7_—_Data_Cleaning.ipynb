# %%
import numpy as np
import pandas as pd

# %%
data = {
    "Name": [
        "Aarav", "Priya", "Rahul", "Sneha", "Aditya",
        "Ananya", "Rohan", "Neha", "Vikram", "Isha"
    ],
    "Age": [20, 21, 19, 20, 22, 21, 20, 19, 22, 21],
    "Gender": [
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female"
    ],
    "Study_Hours": [3, 5, 2, 6, 4, 7, 3, 5, 2, 6],
    "Attendance": [85, 92, 78, 95, 88, 96, 82, 90, 75, 93],
    "Marks": [72, 88, 65, 91, 79, 95, 70, 86, 62, 90]
}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age  Gender  Study_Hours  Attendance  Marks
# 0   Aarav   20    Male            3          85     72
# 1   Priya   21  Female            5          92     88
# 2   Rahul   19    Male            2          78     65
# 3   Sneha   20  Female            6          95     91
# 4  Aditya   22    Male            4          88     79
# 5  Ananya   21  Female            7          96     95
# 6   Rohan   20    Male            3          82     70
# 7    Neha   19  Female            5          90     86
# 8  Vikram   22    Male            2          75     62
# 9    Isha   21  Female            6          93     90

# %%
df.loc[2, "Study_Hours"] = np.nan
df.loc[5, "Attendance"] = np.nan
df.loc[7, "Marks"] = np.nan

df
# Out:
#      Name  Age  Gender  Study_Hours  Attendance  Marks
# 0   Aarav   20    Male          3.0        85.0   72.0
# 1   Priya   21  Female          5.0        92.0   88.0
# 2   Rahul   19    Male          NaN        78.0   65.0
# 3   Sneha   20  Female          6.0        95.0   91.0
# 4  Aditya   22    Male          4.0        88.0   79.0
# 5  Ananya   21  Female          7.0         NaN   95.0
# 6   Rohan   20    Male          3.0        82.0   70.0
# 7    Neha   19  Female          5.0        90.0    NaN
# 8  Vikram   22    Male          2.0        75.0   62.0
# 9    Isha   21  Female          6.0        93.0   90.0

# %%
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# Name           0
# Age            0
# Gender         0
# Study_Hours    1
# Attendance     1
# Marks          1
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

print(missing_percentage)
# Out:
# Name            0.0
# Age             0.0
# Gender          0.0
# Study_Hours    10.0
# Attendance     10.0
# Marks          10.0
# dtype: float64

# %%
df["Study_Hours"] = df["Study_Hours"].fillna(
    df["Study_Hours"].mean()
)

df["Attendance"] = df["Attendance"].fillna(
    df["Attendance"].mean()
)

df["Marks"] = df["Marks"].fillna(
    df["Marks"].mean()
)

# %%
print("Missing values after cleaning:")
print(df.isnull().sum())
# Out:
# Missing values after cleaning:
# Name           0
# Age            0
# Gender         0
# Study_Hours    0
# Attendance     0
# Marks          0
# dtype: int64

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
df = df.drop_duplicates()

print("Dataset shape after removing duplicates:", df.shape)
# Out:
# Dataset shape after removing duplicates: (10, 6)

# %%
print(df.dtypes)
# Out:
# Name            object
# Age              int64
# Gender          object
# Study_Hours    float64
# Attendance     float64
# Marks          float64
# dtype: object
